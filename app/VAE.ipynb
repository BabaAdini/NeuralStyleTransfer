# %%
# !conda install -y keras=2.4.3
# !conda install -y matplotlib=3.4.2
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - keras=2.4.3
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     abseil-cpp-20210324.2      |       h9c3ff4c_0        1010 KB  conda-forge
#     absl-py-0.14.0             |     pyhd8ed1ab_0          97 KB  conda-forge
#     aiohttp-3.7.4.post0        |   py39h3811e60_0         624 KB  conda-forge
#     astor-0.8.1                |     pyh9f0ad1d_0          25 KB  conda-forge
#     astunparse-1.6.3           |     pyhd8ed1ab_0          15 KB  conda-forge
#     async-timeout-3.0.1        |          py_1000          11 KB  conda-forge
#     cachetools-4.2.2           |     pyhd8ed1ab_0          12 KB  conda-forge
#     click-8.0.1                |   py39hf3d152e_0         146 KB  conda-forge
#     dataclasses-0.8            |     pyhc8e2a94_3          10 KB  conda-forge
#     gast-0.3.3                 |             py_0          12 KB  conda-forge
#     giflib-5.2.1               |       h36c2ea0_2          77 KB  conda-forge
#     google-auth-1.35.0         |     pyh6c4a22f_0          81 KB  conda-forge
#     google-auth-oauthlib-0.4.6 |     pyhd8ed1ab_0          19 KB  conda-forge
#     google-pasta-0.2.0         |     pyh8c360ce_0          42 KB  conda-forge
#     grpc-cpp-1.37.1            |       hfc4d69e_3         3.5 MB  conda-forge
#     grpcio-1.37.1              |   py39hff7568b_0         2.2 MB  conda-forge
#     h5py-2.10.0                |nompi_py39h98ba4bc_106         1.1 MB  conda-forge
#     hdf5-1.10.6                |nompi_h6a2412b_1114         3.1 MB  conda-forge
#     jpeg-9d                    |       h36c2ea0_0         264 KB  conda-forge
#     keras-2.4.3                |     pyhd8ed1ab_0          30 KB  conda-forge
#     keras-preprocessing-1.1.2  |     pyhd8ed1ab_0          34 KB  conda-forge
#     libblas-3.9.0              |11_linux64_openblas          12 KB  conda-forge
#     libcblas-3.9.0             |11_linux64_openblas          11 KB  conda-forge
#     libgfortran-ng-11.2.0      |       h69a702a_8          19 KB  conda-forge
#     libgfortran5-11.2.0        |       h5c6108e_8         1.7 MB  conda-forge
#     liblapack-3.9.0            |11_linux64_openblas          11 KB  conda-forge
#     libopenblas-0.3.17         |pthreads_h8fe5266_1         9.2 MB  conda-forge
#     libpng-1.6.37              |       h21135ba_2         306 KB  conda-forge
#     libprotobuf-3.15.8         |       h780b84a_1         2.5 MB  conda-forge
#     markdown-3.3.4             |     pyhd8ed1ab_0          67 KB  conda-forge
#     multidict-5.1.0            |   py39h3811e60_1          68 KB  conda-forge
#     numpy-1.21.2               |   py39hdbf815f_0         6.2 MB  conda-forge
#     opt_einsum-3.3.0           |     pyhd8ed1ab_1          53 KB  conda-forge
#     protobuf-3.15.8            |   py39he80948d_0         336 KB  conda-forge
#     pyasn1-0.4.8               |             py_0          53 KB  conda-forge
#     pyasn1-modules-0.2.7       |             py_0          60 KB  conda-forge
#     python-flatbuffers-1.12    |     pyhd8ed1ab_1          19 KB  conda-forge
#     pyu2f-0.1.5                |     pyhd8ed1ab_0          31 KB  conda-forge
#     pyyaml-5.4.1               |   py39h3811e60_1         196 KB  conda-forge
#     re2-2021.08.01             |       h9c3ff4c_0         220 KB  conda-forge
#     requests-oauthlib-1.3.0    |     pyh9f0ad1d_0          21 KB  conda-forge
#     rsa-4.7.2                  |     pyh44b312d_0          28 KB  conda-forge
#     scipy-1.7.1                |   py39hee8e79c_0        22.0 MB  conda-forge
#     snappy-1.1.8               |       he1b5a44_3          32 KB  conda-forge
#     tensorboard-2.4.1          |     pyhd8ed1ab_1         8.8 MB  conda-forge
#     tensorboard-plugin-wit-1.8.0|     pyh44b312d_0         670 KB  conda-forge
#     tensorflow-2.4.1           |   py39hf3d152e_0          25 KB  conda-forge
#     tensorflow-base-2.4.1      |   py39h23a8cbf_0        91.0 MB  conda-forge
#     tensorflow-estimator-2.4.0 |     pyh9656e83_0         289 KB  conda-forge
#     termcolor-1.1.0            |             py_2           6 KB  conda-forge
#     typing-extensions-3.10.0.2 |       hd8ed1ab_0           8 KB  conda-forge
#     typing_extensions-3.10.0.2 |     pyha770c72_0          28 KB  conda-forge
#     werkzeug-2.0.1             |     pyhd8ed1ab_0         219 KB  conda-forge
#     wrapt-1.12.1               |   py39h3811e60_3          47 KB  conda-forge
#     yarl-1.6.3                 |   py39h3811e60_2         142 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       156.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   abseil-cpp         conda-forge/linux-64::abseil-cpp-20210324.2-h9c3ff4c_0
#   absl-py            conda-forge/noarch::absl-py-0.14.0-pyhd8ed1ab_0
#   aiohttp            conda-forge/linux-64::aiohttp-3.7.4.post0-py39h3811e60_0
#   astor              conda-forge/noarch::astor-0.8.1-pyh9f0ad1d_0
#   astunparse         conda-forge/noarch::astunparse-1.6.3-pyhd8ed1ab_0
#   async-timeout      conda-forge/noarch::async-timeout-3.0.1-py_1000
#   cachetools         conda-forge/noarch::cachetools-4.2.2-pyhd8ed1ab_0
#   click              conda-forge/linux-64::click-8.0.1-py39hf3d152e_0
#   dataclasses        conda-forge/noarch::dataclasses-0.8-pyhc8e2a94_3
#   gast               conda-forge/noarch::gast-0.3.3-py_0
#   giflib             conda-forge/linux-64::giflib-5.2.1-h36c2ea0_2
#   google-auth        conda-forge/noarch::google-auth-1.35.0-pyh6c4a22f_0
#   google-auth-oauth~ conda-forge/noarch::google-auth-oauthlib-0.4.6-pyhd8ed1ab_0
#   google-pasta       conda-forge/noarch::google-pasta-0.2.0-pyh8c360ce_0
#   grpc-cpp           conda-forge/linux-64::grpc-cpp-1.37.1-hfc4d69e_3
#   grpcio             conda-forge/linux-64::grpcio-1.37.1-py39hff7568b_0
#   h5py               conda-forge/linux-64::h5py-2.10.0-nompi_py39h98ba4bc_106
#   hdf5               conda-forge/linux-64::hdf5-1.10.6-nompi_h6a2412b_1114
#   jpeg               conda-forge/linux-64::jpeg-9d-h36c2ea0_0
#   keras              conda-forge/noarch::keras-2.4.3-pyhd8ed1ab_0
#   keras-preprocessi~ conda-forge/noarch::keras-preprocessing-1.1.2-pyhd8ed1ab_0
#   libblas            conda-forge/linux-64::libblas-3.9.0-11_linux64_openblas
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-11_linux64_openblas
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-11.2.0-h69a702a_8
#   libgfortran5       conda-forge/linux-64::libgfortran5-11.2.0-h5c6108e_8
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-11_linux64_openblas
#   libopenblas        conda-forge/linux-64::libopenblas-0.3.17-pthreads_h8fe5266_1
#   libpng             conda-forge/linux-64::libpng-1.6.37-h21135ba_2
#   libprotobuf        conda-forge/linux-64::libprotobuf-3.15.8-h780b84a_1
#   markdown           conda-forge/noarch::markdown-3.3.4-pyhd8ed1ab_0
#   multidict          conda-forge/linux-64::multidict-5.1.0-py39h3811e60_1
#   numpy              conda-forge/linux-64::numpy-1.21.2-py39hdbf815f_0
#   opt_einsum         conda-forge/noarch::opt_einsum-3.3.0-pyhd8ed1ab_1
#   protobuf           conda-forge/linux-64::protobuf-3.15.8-py39he80948d_0
#   pyasn1             conda-forge/noarch::pyasn1-0.4.8-py_0
#   pyasn1-modules     conda-forge/noarch::pyasn1-modules-0.2.7-py_0
#   python-flatbuffers conda-forge/noarch::python-flatbuffers-1.12-pyhd8ed1ab_1
#   pyu2f              conda-forge/noarch::pyu2f-0.1.5-pyhd8ed1ab_0
#   pyyaml             conda-forge/linux-64::pyyaml-5.4.1-py39h3811e60_1
#   re2                conda-forge/linux-64::re2-2021.08.01-h9c3ff4c_0
#   requests-oauthlib  conda-forge/noarch::requests-oauthlib-1.3.0-pyh9f0ad1d_0
#   rsa                conda-forge/noarch::rsa-4.7.2-pyh44b312d_0
#   scipy              conda-forge/linux-64::scipy-1.7.1-py39hee8e79c_0
#   snappy             conda-forge/linux-64::snappy-1.1.8-he1b5a44_3
#   tensorboard        conda-forge/noarch::tensorboard-2.4.1-pyhd8ed1ab_1
#   tensorboard-plugi~ conda-forge/noarch::tensorboard-plugin-wit-1.8.0-pyh44b312d_0
#   tensorflow         conda-forge/linux-64::tensorflow-2.4.1-py39hf3d152e_0
#   tensorflow-base    conda-forge/linux-64::tensorflow-base-2.4.1-py39h23a8cbf_0
#   tensorflow-estima~ conda-forge/noarch::tensorflow-estimator-2.4.0-pyh9656e83_0
#   termcolor          conda-forge/noarch::termcolor-1.1.0-py_2
#   typing-extensions  conda-forge/noarch::typing-extensions-3.10.0.2-hd8ed1ab_0
#   typing_extensions  conda-forge/noarch::typing_extensions-3.10.0.2-pyha770c72_0
#   werkzeug           conda-forge/noarch::werkzeug-2.0.1-pyhd8ed1ab_0
#   wrapt              conda-forge/linux-64::wrapt-1.12.1-py39h3811e60_3
#   yarl               conda-forge/linux-64::yarl-1.6.3-py39h3811e60_2
#
#
#
# Downloading and Extracting Packages
# grpc-cpp-1.37.1      | 3.5 MB    | ##################################### | 100%
# snappy-1.1.8         | 32 KB     | ##################################### | 100%
# typing_extensions-3. | 28 KB     | ##################################### | 100%
# tensorflow-2.4.1     | 25 KB     | ##################################### | 100%
# google-auth-1.35.0   | 81 KB     | ##################################### | 100%
# libblas-3.9.0        | 12 KB     | ##################################### | 100%
# aiohttp-3.7.4.post0  | 624 KB    | ##################################### | 100%
# opt_einsum-3.3.0     | 53 KB     | ##################################### | 100%
# absl-py-0.14.0       | 97 KB     | ##################################### | 100%
# pyyaml-5.4.1         | 196 KB    | ##################################### | 100%
# astor-0.8.1          | 25 KB     | ##################################### | 100%
# re2-2021.08.01       | 220 KB    | ##################################### | 100%
# click-8.0.1          | 146 KB    | ##################################### | 100%
# scipy-1.7.1          | 22.0 MB   | ##################################### | 100%
# jpeg-9d              | 264 KB    | ##################################### | 100%
# tensorboard-plugin-w | 670 KB    | ##################################### | 100%
# grpcio-1.37.1        | 2.2 MB    | ##################################### | 100%
# rsa-4.7.2            | 28 KB     | ##################################### | 100%
# termcolor-1.1.0      | 6 KB      | ##################################### | 100%
# h5py-2.10.0          | 1.1 MB    | ##################################### | 100%
# protobuf-3.15.8      | 336 KB    | ##################################### | 100%
# astunparse-1.6.3     | 15 KB     | ##################################### | 100%
# pyu2f-0.1.5          | 31 KB     | ##################################### | 100%
# libpng-1.6.37        | 306 KB    | ##################################### | 100%
# requests-oauthlib-1. | 21 KB     | ##################################### | 100%
# abseil-cpp-20210324. | 1010 KB   | ##################################### | 100%
# libopenblas-0.3.17   | 9.2 MB    | ##################################### | 100%
# pyasn1-0.4.8         | 53 KB     | ##################################### | 100%
# libcblas-3.9.0       | 11 KB     | ##################################### | 100%
# async-timeout-3.0.1  | 11 KB     | ##################################### | 100%
# yarl-1.6.3           | 142 KB    | ##################################### | 100%
# typing-extensions-3. | 8 KB      | ##################################### | 100%
# markdown-3.3.4       | 67 KB     | ##################################### | 100%
# werkzeug-2.0.1       | 219 KB    | ##################################### | 100%
# libgfortran5-11.2.0  | 1.7 MB    | ##################################### | 100%
# liblapack-3.9.0      | 11 KB     | ##################################### | 100%
# keras-2.4.3          | 30 KB     | ##################################### | 100%
# tensorflow-estimator | 289 KB    | ##################################### | 100%
# tensorboard-2.4.1    | 8.8 MB    | ##################################### | 100%
# cachetools-4.2.2     | 12 KB     | ##################################### | 100%
# libprotobuf-3.15.8   | 2.5 MB    | ##################################### | 100%
# wrapt-1.12.1         | 47 KB     | ##################################### | 100%
# libgfortran-ng-11.2. | 19 KB     | ##################################### | 100%
# keras-preprocessing- | 34 KB     | ##################################### | 100%
# tensorflow-base-2.4. | 91.0 MB   | ##################################### | 100%
# pyasn1-modules-0.2.7 | 60 KB     | ##################################### | 100%
# gast-0.3.3           | 12 KB     | ##################################### | 100%
# multidict-5.1.0      | 68 KB     | ##################################### | 100%
# google-auth-oauthlib | 19 KB     | ##################################### | 100%
# giflib-5.2.1         | 77 KB     | ##################################### | 100%
# python-flatbuffers-1 | 19 KB     | ##################################### | 100%
# google-pasta-0.2.0   | 42 KB     | ##################################### | 100%
# dataclasses-0.8      | 10 KB     | ##################################### | 100%
# numpy-1.21.2         | 6.2 MB    | ##################################### | 100%
# hdf5-1.10.6          | 3.1 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - matplotlib=3.4.2
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     alsa-lib-1.2.3             |       h516909a_0         560 KB  conda-forge
#     cycler-0.10.0              |             py_2           9 KB  conda-forge
#     dbus-1.13.6                |       h48d8840_2         572 KB  conda-forge
#     expat-2.4.1                |       h9c3ff4c_0         182 KB  conda-forge
#     fontconfig-2.13.1          |    hba837de_1005         357 KB  conda-forge
#     freetype-2.10.4            |       h0708190_1         890 KB  conda-forge
#     gettext-0.19.8.1           |    h0b5b191_1005         3.6 MB  conda-forge
#     glib-2.68.4                |       h9c3ff4c_0         447 KB  conda-forge
#     glib-tools-2.68.4          |       h9c3ff4c_0          86 KB  conda-forge
#     gst-plugins-base-1.18.5    |       hf529b03_0         2.6 MB  conda-forge
#     gstreamer-1.18.5           |       h76c114f_0         2.0 MB  conda-forge
#     jbig-2.1                   |    h7f98852_2003          43 KB  conda-forge
#     kiwisolver-1.3.2           |   py39h1a9c180_0          79 KB  conda-forge
#     lcms2-2.12                 |       hddcbb42_0         443 KB  conda-forge
#     lerc-2.2.1                 |       h9c3ff4c_0         213 KB  conda-forge
#     libclang-11.1.0            |default_ha53f305_1        19.2 MB  conda-forge
#     libdeflate-1.7             |       h7f98852_5          67 KB  conda-forge
#     libevent-2.1.10            |       hcdb4288_3         1.1 MB  conda-forge
#     libglib-2.68.4             |       h3e27bee_0         3.0 MB  conda-forge
#     libllvm11-11.1.0           |       hf817b99_2        29.1 MB  conda-forge
#     libogg-1.3.4               |       h7f98852_1         206 KB  conda-forge
#     libopus-1.3.1              |       h7f98852_1         255 KB  conda-forge
#     libpq-13.3                 |       hd57d9b9_0         2.7 MB  conda-forge
#     libtiff-4.3.0              |       hf544144_1         668 KB  conda-forge
#     libuuid-2.32.1             |    h7f98852_1000          28 KB  conda-forge
#     libvorbis-1.3.7            |       h9c3ff4c_0         280 KB  conda-forge
#     libwebp-base-1.2.1         |       h7f98852_0         845 KB  conda-forge
#     libxcb-1.13                |    h7f98852_1003         395 KB  conda-forge
#     libxkbcommon-1.0.3         |       he3ba5ed_0         581 KB  conda-forge
#     matplotlib-3.4.2           |   py39hf3d152e_0           7 KB  conda-forge
#     matplotlib-base-3.4.2      |   py39h2fa2bec_0         7.2 MB  conda-forge
#     mysql-common-8.0.25        |       ha770c72_2         1.6 MB  conda-forge
#     mysql-libs-8.0.25          |       hfa10184_2         1.8 MB  conda-forge
#     nspr-4.30                  |       h9c3ff4c_0         233 KB  conda-forge
#     nss-3.69                   |       hb5efdd6_0         2.1 MB  conda-forge
#     olefile-0.46               |     pyh9f0ad1d_1          32 KB  conda-forge
#     openjpeg-2.4.0             |       hb52868f_1         444 KB  conda-forge
#     pcre-8.45                  |       h9c3ff4c_0         253 KB  conda-forge
#     pillow-8.3.2               |   py39ha612740_0         701 KB  conda-forge
#     pthread-stubs-0.4          |    h36c2ea0_1001           5 KB  conda-forge
#     pyqt-5.12.3                |   py39hf3d152e_7          21 KB  conda-forge
#     pyqt-impl-5.12.3           |   py39h0fcd23e_7         5.9 MB  conda-forge
#     pyqt5-sip-4.19.18          |   py39he80948d_7         310 KB  conda-forge
#     pyqtchart-5.12             |   py39h0fcd23e_7         253 KB  conda-forge
#     pyqtwebengine-5.12.1       |   py39h0fcd23e_7         174 KB  conda-forge
#     qt-5.12.9                  |       hda022c4_4        99.5 MB  conda-forge
#     xorg-libxau-1.0.9          |       h7f98852_0          13 KB  conda-forge
#     xorg-libxdmcp-1.1.3        |       h7f98852_0          19 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       191.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   alsa-lib           conda-forge/linux-64::alsa-lib-1.2.3-h516909a_0
#   cycler             conda-forge/noarch::cycler-0.10.0-py_2
#   dbus               conda-forge/linux-64::dbus-1.13.6-h48d8840_2
#   expat              conda-forge/linux-64::expat-2.4.1-h9c3ff4c_0
#   fontconfig         conda-forge/linux-64::fontconfig-2.13.1-hba837de_1005
#   freetype           conda-forge/linux-64::freetype-2.10.4-h0708190_1
#   gettext            conda-forge/linux-64::gettext-0.19.8.1-h0b5b191_1005
#   glib               conda-forge/linux-64::glib-2.68.4-h9c3ff4c_0
#   glib-tools         conda-forge/linux-64::glib-tools-2.68.4-h9c3ff4c_0
#   gst-plugins-base   conda-forge/linux-64::gst-plugins-base-1.18.5-hf529b03_0
#   gstreamer          conda-forge/linux-64::gstreamer-1.18.5-h76c114f_0
#   jbig               conda-forge/linux-64::jbig-2.1-h7f98852_2003
#   kiwisolver         conda-forge/linux-64::kiwisolver-1.3.2-py39h1a9c180_0
#   lcms2              conda-forge/linux-64::lcms2-2.12-hddcbb42_0
#   lerc               conda-forge/linux-64::lerc-2.2.1-h9c3ff4c_0
#   libclang           conda-forge/linux-64::libclang-11.1.0-default_ha53f305_1
#   libdeflate         conda-forge/linux-64::libdeflate-1.7-h7f98852_5
#   libevent           conda-forge/linux-64::libevent-2.1.10-hcdb4288_3
#   libglib            conda-forge/linux-64::libglib-2.68.4-h3e27bee_0
#   libllvm11          conda-forge/linux-64::libllvm11-11.1.0-hf817b99_2
#   libogg             conda-forge/linux-64::libogg-1.3.4-h7f98852_1
#   libopus            conda-forge/linux-64::libopus-1.3.1-h7f98852_1
#   libpq              conda-forge/linux-64::libpq-13.3-hd57d9b9_0
#   libtiff            conda-forge/linux-64::libtiff-4.3.0-hf544144_1
#   libuuid            conda-forge/linux-64::libuuid-2.32.1-h7f98852_1000
#   libvorbis          conda-forge/linux-64::libvorbis-1.3.7-h9c3ff4c_0
#   libwebp-base       conda-forge/linux-64::libwebp-base-1.2.1-h7f98852_0
#   libxcb             conda-forge/linux-64::libxcb-1.13-h7f98852_1003
#   libxkbcommon       conda-forge/linux-64::libxkbcommon-1.0.3-he3ba5ed_0
#   matplotlib         conda-forge/linux-64::matplotlib-3.4.2-py39hf3d152e_0
#   matplotlib-base    conda-forge/linux-64::matplotlib-base-3.4.2-py39h2fa2bec_0
#   mysql-common       conda-forge/linux-64::mysql-common-8.0.25-ha770c72_2
#   mysql-libs         conda-forge/linux-64::mysql-libs-8.0.25-hfa10184_2
#   nspr               conda-forge/linux-64::nspr-4.30-h9c3ff4c_0
#   nss                conda-forge/linux-64::nss-3.69-hb5efdd6_0
#   olefile            conda-forge/noarch::olefile-0.46-pyh9f0ad1d_1
#   openjpeg           conda-forge/linux-64::openjpeg-2.4.0-hb52868f_1
#   pcre               conda-forge/linux-64::pcre-8.45-h9c3ff4c_0
#   pillow             conda-forge/linux-64::pillow-8.3.2-py39ha612740_0
#   pthread-stubs      conda-forge/linux-64::pthread-stubs-0.4-h36c2ea0_1001
#   pyqt               conda-forge/linux-64::pyqt-5.12.3-py39hf3d152e_7
#   pyqt-impl          conda-forge/linux-64::pyqt-impl-5.12.3-py39h0fcd23e_7
#   pyqt5-sip          conda-forge/linux-64::pyqt5-sip-4.19.18-py39he80948d_7
#   pyqtchart          conda-forge/linux-64::pyqtchart-5.12-py39h0fcd23e_7
#   pyqtwebengine      conda-forge/linux-64::pyqtwebengine-5.12.1-py39h0fcd23e_7
#   qt                 conda-forge/linux-64::qt-5.12.9-hda022c4_4
#   xorg-libxau        conda-forge/linux-64::xorg-libxau-1.0.9-h7f98852_0
#   xorg-libxdmcp      conda-forge/linux-64::xorg-libxdmcp-1.1.3-h7f98852_0
#
#
#
# Downloading and Extracting Packages
# kiwisolver-1.3.2     | 79 KB     | ##################################### | 100%
# olefile-0.46         | 32 KB     | ##################################### | 100%
# xorg-libxau-1.0.9    | 13 KB     | ##################################### | 100%
# pillow-8.3.2         | 701 KB    | ##################################### | 100%
# pyqt-5.12.3          | 21 KB     | ##################################### | 100%
# glib-2.68.4          | 447 KB    | ##################################### | 100%
# alsa-lib-1.2.3       | 560 KB    | ##################################### | 100%
# mysql-libs-8.0.25    | 1.8 MB    | ##################################### | 100%
# gstreamer-1.18.5     | 2.0 MB    | ##################################### | 100%
# pcre-8.45            | 253 KB    | ##################################### | 100%
# libclang-11.1.0      | 19.2 MB   | ##################################### | 100%
# glib-tools-2.68.4    | 86 KB     | ##################################### | 100%
# dbus-1.13.6          | 572 KB    | ##################################### | 100%
# libwebp-base-1.2.1   | 845 KB    | ##################################### | 100%
# libxcb-1.13          | 395 KB    | ##################################### | 100%
# libopus-1.3.1        | 255 KB    | ##################################### | 100%
# libllvm11-11.1.0     | 29.1 MB   | ##################################### | 100%
# qt-5.12.9            | 99.5 MB   | ##################################### | 100%
# expat-2.4.1          | 182 KB    | ##################################### | 100%
# libtiff-4.3.0        | 668 KB    | ##################################### | 100%
# libxkbcommon-1.0.3   | 581 KB    | ##################################### | 100%
# mysql-common-8.0.25  | 1.6 MB    | ##################################### | 100%
# matplotlib-3.4.2     | 7 KB      | ##################################### | 100%
# libvorbis-1.3.7      | 280 KB    | ##################################### | 100%
# libuuid-2.32.1       | 28 KB     | ##################################### | 100%
# libpq-13.3           | 2.7 MB    | ##################################### | 100%
# libevent-2.1.10      | 1.1 MB    | ##################################### | 100%
# xorg-libxdmcp-1.1.3  | 19 KB     | ##################################### | 100%
# lerc-2.2.1           | 213 KB    | ##################################### | 100%
# jbig-2.1             | 43 KB     | ##################################### | 100%
# freetype-2.10.4      | 890 KB    | ##################################### | 100%
# cycler-0.10.0        | 9 KB      | ##################################### | 100%
# matplotlib-base-3.4. | 7.2 MB    | ##################################### | 100%
# pyqtchart-5.12       | 253 KB    | ##################################### | 100%
# lcms2-2.12           | 443 KB    | ##################################### | 100%
# pyqtwebengine-5.12.1 | 174 KB    | ##################################### | 100%
# libogg-1.3.4         | 206 KB    | ##################################### | 100%
# gst-plugins-base-1.1 | 2.6 MB    | ##################################### | 100%
# nspr-4.30            | 233 KB    | ##################################### | 100%
# fontconfig-2.13.1    | 357 KB    | ##################################### | 100%
# pyqt5-sip-4.19.18    | 310 KB    | ##################################### | 100%
# pthread-stubs-0.4    | 5 KB      | ##################################### | 100%
# gettext-0.19.8.1     | 3.6 MB    | ##################################### | 100%
# openjpeg-2.4.0       | 444 KB    | ##################################### | 100%
# nss-3.69             | 2.1 MB    | ##################################### | 100%
# pyqt-impl-5.12.3     | 5.9 MB    | ##################################### | 100%
# libglib-2.68.4       | 3.0 MB    | ##################################### | 100%
# libdeflate-1.7       | 67 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
import keras
keras.__version__
# Out:
# '2.4.3'

# %%
import tensorflow as tf
import keras
from keras import layers
from keras import backend as K
from keras.models import Model
import numpy as np
from keras.datasets import mnist

# %%
from keras import backend as K
K.clear_session()

# %%
tf.compat.v1.disable_eager_execution()

# %%
img_shape = (28, 28, 1)
batch_size = 16
latent_dim = 2  # Dimensionality of the latent space: a plane

input_img = keras.Input(shape=img_shape)

x = layers.Conv2D(32, 3,
                  padding='same', activation='relu')(input_img)
x = layers.Conv2D(64, 3,
                  padding='same', activation='relu',
                  strides=(2, 2))(x)
x = layers.Conv2D(64, 3,
                  padding='same', activation='relu')(x)
x = layers.Conv2D(64, 3,
                  padding='same', activation='relu')(x)
shape_before_flattening = K.int_shape(x)

x = layers.Flatten()(x)
x = layers.Dense(32, activation='relu')(x)

z_mean = layers.Dense(latent_dim)(x)
z_log_var = layers.Dense(latent_dim)(x)
# This is our encoder model.
encoder = Model(input_img, [z_mean, z_log_var])

# # We then apply it to `z` to recover the decoded `z`.
# z_decoded = decoder(z)

# %%
def sampling(args):
    z_mean, z_log_var = args
    epsilon = K.random_normal(shape=(K.shape(z_mean)[0], latent_dim),
                              mean=0., stddev=1.)
    return z_mean + K.exp(z_log_var) * epsilon

z = layers.Lambda(sampling)([z_mean, z_log_var])

# %%
# This is the input where we will feed `z`.
decoder_input = layers.Input(K.int_shape(z)[1:])

# Upsample to the correct number of units
x = layers.Dense(np.prod(shape_before_flattening[1:]),
                 activation='relu')(decoder_input)

# Reshape into an image of the same shape as before our last `Flatten` layer
x = layers.Reshape(shape_before_flattening[1:])(x)

# We then apply then reverse operation to the initial
# stack of convolution layers: a `Conv2DTranspose` layers
# with corresponding parameters.
x = layers.Conv2DTranspose(32, 3,
                           padding='same', activation='relu',
                           strides=(2, 2))(x)
x = layers.Conv2D(1, 3,
                  padding='same', activation='sigmoid')(x)
# We end up with a feature map of the same size as the original input.

# This is our decoder model.
decoder = Model(decoder_input, x)

# We then apply it to `z` to recover the decoded `z`.
z_decoded = decoder(z)

# %% [markdown]
# # Not to be Executed!!!!

# %%
# Encode the input into a mean and variance parameter
z_mean, z_log_variance = encoder(input_img)

# Draw a latent point using a small random epsilon
z = z_mean + K.exp(z_log_variance) * epsilon

# Then decode z back to an image
reconstructed_img = decoder(z)

# Instantiate a model
model = Model(input_img, reconstructed_img)

# Then train the model using 2 losses:
# a reconstruction loss and a regularization loss

# %%
class CustomVariationalLayer(keras.layers.Layer):

    def vae_loss(self, x, z_decoded):
        x = K.flatten(x)
        z_decoded = K.flatten(z_decoded)
        xent_loss = keras.metrics.binary_crossentropy(x, z_decoded)
        kl_loss = -5e-4 * K.mean(
            1 + z_log_var - K.square(z_mean) - K.exp(z_log_var), axis=-1)
        return K.mean(xent_loss + kl_loss)

    def call(self, inputs):
        x = inputs[0]
        z_decoded = inputs[1]
        loss = self.vae_loss(x, z_decoded)
        self.add_loss(loss, inputs=inputs)
        # We don't use this output.
        return x

# We call our custom layer on the input and the decoded output,
# to obtain the final model output.
y = CustomVariationalLayer()([input_img, z_decoded])

# %%
vae = Model(input_img, y)
vae.compile(optimizer='rmsprop', loss=None)
vae.summary()

# Train the VAE on MNIST digits
(x_train, _), (x_test, y_test) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_train = x_train.reshape(x_train.shape + (1,))
x_test = x_test.astype('float32') / 255.
x_test = x_test.reshape(x_test.shape + (1,))

vae.fit(x=x_train, y=None,
        shuffle=True,
        epochs=10,
        batch_size=batch_size,
        validation_data=(x_test, None))
# Out:
# WARNING:tensorflow:Output custom_variational_layer missing from loss dictionary. We assume this was done on purpose. The fit and evaluate APIs will not be expecting any data to be passed to custom_variational_layer.
# Model: "functional_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 28, 28, 1)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 28, 28, 32)   320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 14, 14, 64)   18496       conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 14, 14, 64)   36928       conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 14, 14, 64)   36928       conv2d_2[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 12544)        0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 32)           401440      flatten[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 2)            66          dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 2)            66          dense[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 2)            0           dense_1[0][0]
#                                                                  dense_2[0][0]
# __________________________________________________________________________________________________
# functional_3 (Functional)       (None, 28, 28, 1)    56385       lambda[0][0]
# __________________________________________________________________________________________________
# custom_variational_layer (Custo (None, 28, 28, 1)    0           input_1[0][0]
#                                                                  functional_3[0][0]
# ==================================================================================================
# Total params: 550,629
# Trainable params: 550,629
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 [==============================] - ETA: 0s - loss: 0.2207WARNING:tensorflow:From /home/kabir/anaconda3/envs/KbLab/lib/python3.8/site-packages/tensorflow/python/keras/engine/training_v1.py:2048: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# 60000/60000 [==============================] - 233s 4ms/sample - loss: 0.2207 - val_loss: 0.2015
# Epoch 2/10
# 60000/60000 [==============================] - 252s 4ms/sample - loss: 0.1977 - val_loss: 0.1961
# Epoch 3/10
# 60000/60000 [==============================] - 241s 4ms/sample - loss: 0.1936 - val_loss: 0.1930
# Epoch 4/10
# 60000/60000 [==============================] - 230s 4ms/sample - loss: 0.1914 - val_loss: 0.1901
# Epoch 5/10
# 60000/60000 [==============================] - 233s 4ms/sample - loss: 0.1899 - val_loss: 0.1909
# Epoch 6/10
# 60000/60000 [==============================] - 229s 4ms/sample - loss: 0.1890 - val_loss: 0.1885
# Epoch 7/10
# 60000/60000 [==============================] - 225s 4ms/sample - loss: 0.1878 - val_loss: 0.1878
# Epoch 8/10
# 60000/60000 [==============================] - 225s 4ms/sample - loss: 0.1870 - val_loss: 0.1854
# Epoch 9/10
# 60000/60000 [==============================] - 240s 4ms/sample - loss: 0.1866 - val_loss: 0.1871
# Epoch 10/10
# 60000/60000 [==============================] - 241s 4ms/sample - loss: 0.1860 - val_loss: 0.1863

# %%
import matplotlib.pyplot as plt
from scipy.stats import norm

# Display a 2D manifold of the digits
n = 15  # figure with 15x15 digits
digit_size = 28
figure = np.zeros((digit_size * n, digit_size * n))
# Linearly spaced coordinates on the unit square were transformed
# through the inverse CDF (ppf) of the Gaussian
# to produce values of the latent variables z,
# since the prior of the latent space is Gaussian
grid_x = norm.ppf(np.linspace(0.05, 0.95, n))
grid_y = norm.ppf(np.linspace(0.05, 0.95, n))

for i, yi in enumerate(grid_x):
    for j, xi in enumerate(grid_y):
        z_sample = np.array([[xi, yi]])
        z_sample = np.tile(z_sample, batch_size).reshape(batch_size, 2)
        x_decoded = decoder.predict(z_sample, batch_size=batch_size)
        digit = x_decoded[0].reshape(digit_size, digit_size)
        figure[i * digit_size: (i + 1) * digit_size,
               j * digit_size: (j + 1) * digit_size] = digit

plt.figure(figsize=(10, 10))
plt.imshow(figure, cmap='Greys_r')
plt.show()
